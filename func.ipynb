# %%
def funcaoUm():
    print("Olá Mundo!")

funcaoUm()
# Out:
# Olá Mundo!

# %%
def funcaoDois(num1,num2):
    soma = num1 + num2
    print("A soma é: ",soma)

funcaoDois(100,750)
# Out:
# A soma é:  850

# %%
def funcaoNome(nome):
    print("Olá,", nome)

funcaoNome(input("Digite seu nome:"))
# Out:
# Olá, Felipe

# %%
import statistics as st

def media():
    n1 = float(input("Digite a primeira nota: "))
    n2 = float(input("Digite a segunda nota: "))
    n3 = float(input("Digite a terceira nota: "))
    n4 = float(input("Digite a quarta nota: "))

    notas = (n1,n2,n3,n4)
    media = st.mean(list(notas))
    medianotas = (n1 + n2 + n3 + n4) / 4


    if media < 6:
        print("O aluno está de recuperação!")
        print("A média é: ",medianotas)
    elif media < 4:
        print("O aluno está de reprovado!")
        print("A média é: ",medianotas)
    else:
        print("O aluno está aprovado! Parabéns!")
        print("A média é: ",medianotas)

media()
# Out:
# O aluno está aprovado! Parabéns!
# A média é:  9.0
